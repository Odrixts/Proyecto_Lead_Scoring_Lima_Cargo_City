# %% [markdown]
# # EDA

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/USER/Desktop/DSD4B (ZERO TO HERO)/03_MACHINE_LEARNING/08_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat.apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
pd.set_option('display.max_rows', 100)
frecuencias_cat(cat)
# Out:
#                  Variable                              Valor  Frecuencia
# 22                 ambito                         Aerolineas    0.051927
# 26                 ambito                               Null    0.091006
# 27                 ambito                              Otros    0.098501
# 24                 ambito                       Exportadores    0.153640
# 25                 ambito                       Importadores    0.218594
# 23                 ambito                   Agentes de Carga    0.386331
# 37     conociste_facebook                              Otros    0.000714
# 36     conociste_facebook                                 No    0.999286
# 33       conociste_google                              Otros    0.001963
# 32       conociste_google                                 No    0.998037
# 35    conociste_periodico                              Otros    0.000178
# 34    conociste_periodico                                 No    0.999822
# 39  conociste_referencias                              Otros    0.001071
# 38  conociste_referencias                                 No    0.998929
# 41            descarga_lm                                Yes    0.380086
# 40            descarga_lm                                 No    0.619914
# 8                  fuente                              Otros    0.031049
# 9                  fuente                          Reference    0.036938
# 4                  fuente                               Chat    0.055496
# 7                  fuente                     Organic Search    0.152570
# 5                  fuente                     Direct Traffic    0.336724
# 6                  fuente                             Google    0.387223
# 11        no_enviar_email                                Yes    0.089936
# 10        no_enviar_email                                 No    0.910064
# 13              no_llamar                              Otros    0.000357
# 12              no_llamar                                 No    0.999643
# 30              ocupacion                              Otros    0.004640
# 31              ocupacion              Supervisor de almacen    0.022841
# 29              ocupacion  Gerente de operaciones logisticas    0.078158
# 28              ocupacion             Asistente de logistica    0.894361
# 3                  origen                              Otros    0.005710
# 2                  origen                      Lead Add Form    0.041934
# 0                  origen                                API    0.300857
# 1                  origen            Landing Page Submission    0.651499
# 17          ult_actividad                 Email Link Clicked    0.027302
# 16          ult_actividad                      Email Bounced    0.039079
# 14          ult_actividad                  Chat Conversation    0.052641
# 19          ult_actividad                              Otros    0.056031
# 15          ult_actividad                  Converted to Lead    0.057994
# 20          ult_actividad            Page Visited on Website    0.083869
# 21          ult_actividad                           SMS Sent    0.300143
# 18          ult_actividad                       Email Opened    0.382941

# %%
cat=cat.loc[(cat.no_llamar != 'Otros') & (cat.no_enviar_email != 'Yes') & (cat.ult_actividad != 'Email Bounced')] \
    .drop(columns=['conociste_facebook',
                  'conociste_google',
                  'conociste_periodico',
                  'conociste_referencias',
                  'no_enviar_email',
                  'no_llamar'
                  ])

# %%
cat.shape
# Out:
# (5088, 6)

# %%
num.shape
# Out:
# (5604, 6)

# %%
num=num[num.index.isin(cat.index)]

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (29, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat)
plt.show()

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                         count        mean  median         std   min    25%  \
# compra                 5088.0    0.414701     0.0    0.492719   0.0    0.0
# visitas_total          5088.0    4.193396     3.0    3.444802   0.0    2.0
# tiempo_en_site_total   5088.0  613.674921   380.0  553.190145   0.0  139.0
# paginas_vistas_visita  5088.0    2.909974     2.5    1.886905   0.0    2.0
# score_actividad        5088.0   14.045991    14.0    0.974134   7.0   14.0
# score_perfil           5088.0     16.3068    16.0    1.421014  11.0   16.0
#
#                          50%      75%     max
# compra                   0.0      1.0     1.0
# visitas_total            3.0      5.0    50.0
# tiempo_en_site_total   380.0  1103.25  2272.0
# paginas_vistas_visita    2.5      4.0    20.0
# score_actividad         14.0     14.0    18.0
# score_perfil            16.0     17.0    20.0

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)
    
    plt.show()

# %%
graficos_eda_continuas(num)

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
