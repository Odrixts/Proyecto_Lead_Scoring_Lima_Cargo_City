# %% [markdown]
# # PRESELECCIÓN DE VARIABLES

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.inspection import permutation_importance


#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/USER/Desktop/DSD4B (ZERO TO HERO)/03_MACHINE_LEARNING/08_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)

# %% [markdown]
# ## MÉTODOS SUPERVISADOS

# %% [markdown]
# ### Preparar x e y

# %%
target = 'compra'
x = df.drop(columns = target).copy()
y =  df[target].copy()

# %% [markdown]
# ### Mutual Information

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)

# %% [markdown]
# #### Calcular y revisar

# %%
mutual_selector = mutual_info_classif(x,y)

rank_mi = ranking_mi(mutual_selector, modo = 'grafico')
plt.show()

# %% [markdown]
# #### Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 22

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_mi = ranking_mi(mutual_selector).iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_mi = x[entran_mi].copy()

# %% [markdown]
# ### Recursive Feature Elimination

# %% [markdown]
# #### Instanciar

# %%
rfe = RFE(estimator = XGBClassifier( n_jobs = -1, eval_metric='auc'))

# %% [markdown]
# #### Entrenar

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBClassifier(base_score=None, booster=None, callbacks=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, device=None,
#                             early_stopping_rounds=None,
#                             enable_categorical=False, eval_metric='auc',
#                             feature_types=None, gamma=None, grow_policy=None,
#                             importance_type=None, interaction_constraints=None,
#                             learning_rate=None, max_bin=None,
#                             max_cat_threshold=None, max_cat_to_onehot=None,
#                             max_delta_step=None, max_depth=None,
#                             max_leaves=None, min_child_weight=None, missing=nan,
#                             monotone_constraints=None, multi_strategy=None,
#                             n_estimators=None, n_jobs=-1,
#                             num_parallel_tree=None, random_state=None, ...))

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_rfe = x.columns[rfe.support_]

# %%
#Son 16
entran_rfe
# Out:
# Index(['origen_Lead Add Form', 'fuente_Direct Traffic', 'fuente_Reference',
#        'ult_actividad_Chat Conversation', 'ult_actividad_Converted to Lead',
#        'ult_actividad_Page Visited on Website', 'ult_actividad_SMS Sent',
#        'ambito_Agentes de Carga', 'ambito_Exportadores', 'ambito_Null',
#        'ocupacion_Asistente de logistica',
#        'ocupacion_Gerente de operaciones logisticas', 'descarga_lm_No',
#        'visitas_total_mms', 'tiempo_en_site_total_mms', 'score_actividad_mms',
#        'score_perfil_mms'],
#       dtype='object')

# %% [markdown]
# #### Crear el dataframe con la selección

# %%
x_rfe = x[entran_rfe].copy()

# %% [markdown]
# ### Permutation Importance

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def ranking_per(predictoras,permutacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)

# %% [markdown]
# #### Instanciar y entrenar

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r'.*Use subset.*of np.ndarray is not recommended')

xgb = XGBClassifier(n_jobs = -1, eval_metric='auc')

xgb.fit(x,y)

permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',
                                     n_repeats=5, n_jobs = -1)

# %% [markdown]
# #### Revisar la salida

# %%
rank_per = ranking_per(x,permutacion)

rank_per.set_index('variable').importancia_per.sort_values().plot.barh(figsize = (12,20));
plt.show()

# %% [markdown]
# #### Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 18

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_per = rank_per.iloc[0:posicion_variable_limite].variable

# %%
entran_per
# Out:
# 30                       tiempo_en_site_total_mms
# 32                            score_actividad_mms
# 29                              visitas_total_mms
# 33                               score_perfil_mms
# 16                         ult_actividad_SMS Sent
# 31                      paginas_vistas_visita_mms
# 24    ocupacion_Gerente de operaciones logisticas
# 21                                    ambito_Null
# 23               ocupacion_Asistente de logistica
# 15          ult_actividad_Page Visited on Website
# 11                ult_actividad_Converted to Lead
# 18                        ambito_Agentes de Carga
# 10                ult_actividad_Chat Conversation
# 0                                      origen_API
# 19                            ambito_Exportadores
# 20                            ambito_Importadores
# 27                                 descarga_lm_No
# 1                  origen_Landing Page Submission
# Name: variable, dtype: object

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_per = x[entran_per].copy()

# %% [markdown]
# ## SELECCIONAR EL MÉTODO FINAL

# %% [markdown]
# Descomentar el método de preselección elegido y dejar comentados el resto.

# %%
#x_preseleccionado = x_mi
#x_preseleccionado = x_rfe
x_preseleccionado = x_per

# %% [markdown]
# ## MÉTODOS NO SUPERVISADOS

# %% [markdown]
# ### Correlación

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %% [markdown]
# #### Calcular y revisar

# %% [markdown]
# ##### Calcular

# %%
cor_finales = correlaciones_fuertes(x_preseleccionado)

# %% [markdown]
# ##### Revisar agregado

# %%
cor_finales.var1.value_counts()
# Out:
# var1
# origen_Landing Page Submission      2
# origen_API                          2
# ambito_Agentes de Carga             2
# ambito_Null                         2
# ocupacion_Asistente de logistica    1
# visitas_total_mms                   1
# descarga_lm_No                      1
# paginas_vistas_visita_mms           1
# Name: count, dtype: int64

# %% [markdown]
# ##### Revisar detalle

# %%
cor_finales.head(50)
# Out:
#                                  var1  \
# 319    origen_Landing Page Submission
# 150  ocupacion_Asistente de logistica
# 41                  visitas_total_mms
# 305                    descarga_lm_No
# 237                        origen_API
# 250                        origen_API
# 213           ambito_Agentes de Carga
# 139                       ambito_Null
# 309    origen_Landing Page Submission
# 143                       ambito_Null
# 212           ambito_Agentes de Carga
# 107         paginas_vistas_visita_mms
#
#                                             var2      corr
# 319                                   origen_API  0.885605
# 150  ocupacion_Gerente de operaciones logisticas  0.836621
# 41                     paginas_vistas_visita_mms  0.566162
# 305               origen_Landing Page Submission  0.503954
# 237                             score_perfil_mms  0.459067
# 250                               descarga_lm_No  0.444411
# 213                          ambito_Importadores  0.429559
# 139                                   origen_API  0.411569
# 309                             score_perfil_mms  0.388415
# 143               origen_Landing Page Submission  0.373624
# 212                          ambito_Exportadores  0.339355
# 107               origen_Landing Page Submission  0.320631

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['tiempo_en_site_total_mms',
#  'score_actividad_mms',
#  'visitas_total_mms',
#  'score_perfil_mms',
#  'ult_actividad_SMS Sent',
#  'paginas_vistas_visita_mms',
#  'ocupacion_Gerente de operaciones logisticas',
#  'ambito_Null',
#  'ocupacion_Asistente de logistica',
#  'ult_actividad_Page Visited on Website',
#  'ult_actividad_Converted to Lead',
#  'ambito_Agentes de Carga',
#  'ult_actividad_Chat Conversation',
#  'origen_API',
#  'ambito_Exportadores',
#  'ambito_Importadores',
#  'descarga_lm_No',
#  'origen_Landing Page Submission']

# %% [markdown]
# #### Filtrar variables

# %% [markdown]
# Meter en una lista las que queramos descartar por alta correlacion y eliminarlas.

# %%
a_eliminar_corr = ['origen_Landing Page Submission','descarga_lm_No','origen_API']

# %%
x_preseleccionado.drop(columns = a_eliminar_corr, inplace = True)

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['tiempo_en_site_total_mms',
#  'score_actividad_mms',
#  'visitas_total_mms',
#  'score_perfil_mms',
#  'ult_actividad_SMS Sent',
#  'paginas_vistas_visita_mms',
#  'ocupacion_Gerente de operaciones logisticas',
#  'ambito_Null',
#  'ocupacion_Asistente de logistica',
#  'ult_actividad_Page Visited on Website',
#  'ult_actividad_Converted to Lead',
#  'ambito_Agentes de Carga',
#  'ult_actividad_Chat Conversation',
#  'ambito_Exportadores',
#  'ambito_Importadores']

# %% [markdown]
# ## GUARDAR DATASETS TRAS PRESELECCION DE VARIABLES

# %%
#Definir los nombres de los archivos
nombre_x_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'x_preseleccionado.pickle'
nombre_y_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'y_preseleccionado.pickle'

# %%
#Guardar los archivos
x_preseleccionado.to_pickle(nombre_x_preseleccionado)

y_preseleccionado = y.copy()
y_preseleccionado.to_pickle(nombre_y_preseleccionado)

# %%
#Guardar los nombres de las variables finales
nombre_variables_finales = ruta_proyecto + '/05_Resultados/' + 'variables_finales.pickle'

x_preseleccionado.iloc[0].to_pickle(nombre_variables_finales)
